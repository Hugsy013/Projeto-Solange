# %% [markdown]
# # AVA2 - Turma 4 - objetivo: fazer uma análise exploratória do dados
# #### Entrega: até às 23h59 do dia 30/04/2025

# %%
########################################################################################################################
# Nomes e RAS
#
#
#
#

# %% [markdown]
# # Importanto pacotes

# %%
# Carrega a biblioteca pandas e atribui um alias chamado "pd"
import pandas as pd
import numpy as np
# Visualização de dados
import matplotlib.pyplot as plt
import seaborn as sns

# Deixar colunas e linhas aparentes
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Conectando com o drive

# %%
# Conexão com o drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Leitura da tabela de dados

# %%
# Faz a leitura do arquivo igm_modificado.xlsx
df = pd.read_excel('/content/drive/MyDrive/Projeto-Solange/igm_modificado.xlsx')

# Mostra o número de linhas e de colunas do df
df.shape
# Out:
# (0, 0)

# %% [markdown]
# ### 1. Faça as checagens dos dados: utilize 3 comandos que vimos em sala de aula. Um deles, obrigatoriamente, deve ser a sinalização se há ou não dados faltantes em cada uma das colunas. Analise os resultados com suas próprias palavras (0,5 ponto)

# %%
print("\nInformacoes gerais sobre o dataframe:")
print(df.info())
# Out:
# Informacoes gerais sobre o dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame
# None

# %%
print("\nResumo estatistico das variaveis numericas:")
print(df.describe())
# Out:
# Resumo estatistico das variaveis numericas:
#          codigo_mun      capital     populacao           area  densidade_dem  \
# count  5.570000e+03  5570.000000  5.570000e+03    5570.000000    5566.000000
# mean   3.253591e+06     0.004847  3.700432e+04    1526.532426     108.189026
# std    9.849103e+05     0.069461  2.170133e+05    5607.553417     572.067148
# min    1.100015e+06     0.000000  8.150000e+02       3.570000       0.100000
# 25%    2.512126e+06     0.000000  5.482750e+03     204.245000      11.600000
# 50%    3.146280e+06     0.000000  1.158400e+04     417.980000      24.400000
# 75%    4.119190e+06     0.000000  2.509850e+04    1026.165000      51.700000
# max    5.300108e+06     1.000000  1.203818e+07  159533.260000   13024.600000
#
#                 pib         pib_pc  participacao_transf_receita  \
# count  5.570000e+03    5570.000000                  4893.000000
# mean   9.544801e+05   17374.483108                    82.316575
# std    9.502661e+06   20133.341193                    11.272136
# min    9.678440e+03    3241.290000                     0.000000
# 25%    5.922529e+04    7077.357500                    77.000000
# 50%    1.301531e+05   12621.810000                    85.000000
# 75%    3.426808e+05   21262.387500                    91.000000
# max    5.707062e+08  715193.700000                   100.000000
#
#           servidores  comissionados  comissionados_por_servidor  \
# count    5233.000000    5570.000000                 5233.000000
# mean      771.324861      96.371275                    0.596191
# std      3209.755931     234.994469                    6.820929
# min         1.000000       0.000000                    0.000000
# 25%       190.000000      24.000000                    0.080000
# 50%       329.000000      45.000000                    0.130000
# 75%       663.000000      92.000000                    0.220000
# max    134273.000000    7240.000000                  331.000000
#
#        perc_pop_econ_ativa  taxa_empreendedorismo  anos_estudo_empreendedor  \
# count          5565.000000            5570.000000               5570.000000
# mean              0.936503               0.250939                  6.124378
# std               0.178640               0.098014                  1.462946
# min               0.290000               0.000000                  0.000000
# 25%               0.810000               0.190000                  5.039926
# 50%               0.940000               0.230000                  6.049990
# 75%               1.050000               0.290000                  7.175247
# max               1.640000               0.770000                 11.553164
#
#        jornada_trabalho  gasto_pc_saude  hab_p_medico     exp_vida  \
# count       5570.000000     4881.000000   4951.000000  5565.000000
# mean          41.414005      604.508021   1801.408820    73.088996
# std            5.193799      282.184671   2203.553117     2.680715
# min            0.000000        3.800000     85.746835    65.300000
# 25%           38.151867      416.930000    967.636243    71.150000
# 50%           41.718024      537.480000   1457.062500    73.470000
# 75%           44.682323      717.760000   2119.679487    75.160000
# max           68.528406     3066.740000  78464.666667    78.640000
#
#        gasto_pc_educacao  exp_anos_estudo  nota_ciencias  nota_humanas  \
# count        4880.000000      5565.000000    5558.000000   5558.000000
# mean          769.775533         9.463639     460.124417    509.526944
# std           277.841845         1.098269      19.275298     23.816077
# min            56.600000         4.340000     385.000000    373.800000
# 25%           585.892500         8.750000     446.324306    492.975737
# 50%           731.825000         9.470000     457.549922    508.987016
# 75%           898.625000        10.210000     471.752760    526.405985
# max          3695.930000        12.830000     550.566667    595.160000
#
#        nota_linguagem     nota_mat  nota_redacao         idhm  \
# count     5557.000000  5557.000000   5557.000000  4986.000000
# mean       499.286922   465.007784    501.840952     0.518626
# std         22.056169    28.496300     44.904955     0.171847
# min        404.000000   369.275000    320.000000     0.000000
# 25%        483.454286   443.078082    473.125000     0.375000
# 50%        499.105769   461.261538    502.406015     0.535000
# 75%        515.125917   483.773196    532.173913     0.659000
# max        571.659503   603.415000    668.000000     1.000000
#
#        indice_governanca
# count        3303.000000
# mean            0.501959
# std             0.083704
# min             0.258000
# 25%             0.438000
# 50%             0.504000
# 75%             0.566000
# max             0.767000

# %%
print("\nChecagem de dados faltantes:")
print(df.isnull().sum())
# Out:
# Checagem de dados faltantes:
# regiao                            0
# estado                            0
# municipio                         0
# codigo_mun                        0
# capital                           0
# porte                             0
# populacao                         0
# area                              0
# densidade_dem                     4
# pib                               0
# pib_pc                            0
# participacao_transf_receita     677
# servidores                      337
# comissionados                     0
# comissionados_por_servidor      337
# perc_pop_econ_ativa               5
# taxa_empreendedorismo             0
# anos_estudo_empreendedor          0
# jornada_trabalho                  0
# gasto_pc_saude                  689
# hab_p_medico                    619
# exp_vida                          5
# gasto_pc_educacao               690
# exp_anos_estudo                   5
# nota_ciencias                    12
# nota_humanas                     12
# nota_linguagem                   13
# nota_mat                         13
# nota_redacao                     13
# idhm                            584
# ranking_igm                    2267
# indice_governanca              2267
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
missing_values.plot(kind='bar', color='skyblue')
plt.title('Quantidade de Dados Faltantes por Coluna')
plt.xlabel('Colunas')
plt.ylabel('Número de Dados Faltantes')
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Observamos que algumas variaveis possuem dados faltantes. Isso e importante pois influencia as analises futuras.

# %% [markdown]
# ### 2.	Faça a frequência simples e relativa de 2 variáveis categóricas. Analise os resultados com suas próprias palavras (0,5 ponto)

# %%
print("\nFrequencia simples - Regiao:")
print(df['regiao'].value_counts())

print("\nFrequencia simples - Porte:")
print(df['porte'].value_counts())
# Out:
# Frequencia simples - Regiao:
# regiao
# NORDESTE        1794
# SUDESTE         1668
# SUL             1191
# CENTRO-OESTE     467
# NORTE            450
# Name: count, dtype: int64
#
# Frequencia simples - Porte:
# porte
# Pequeno porte 1    3810
# Pequeno porte 2    1101
# MÃ©dio porte        350
# Grande porte        309
# Name: count, dtype: int64

# %%
print("\nFrequencia relativa - Regiao:")
print(df['regiao'].value_counts(normalize=True))

print("\nFrequencia relativa - Porte:")
print(df['porte'].value_counts(normalize=True))
# Out:
# Frequencia relativa - Regiao:
# regiao
# NORDESTE        0.322083
# SUDESTE         0.299461
# SUL             0.213824
# CENTRO-OESTE    0.083842
# NORTE           0.080790
# Name: proportion, dtype: float64
#
# Frequencia relativa - Porte:
# porte
# Pequeno porte 1    0.684022
# Pequeno porte 2    0.197666
# MÃ©dio porte       0.062837
# Grande porte       0.055476
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Dados de frequência simples
frequencia_regiao = pd.Series({
    'NORDESTE': 1794,
    'SUDESTE': 1668,
    'SUL': 1191,
    'CENTRO-OESTE': 467,
    'NORTE': 450
})

frequencia_porte = pd.Series({
    'Pequeno porte 1': 3810,
    'Pequeno porte 2': 1101,
    'Médio porte': 350,
    'Grande porte': 309
})

# Gráfico de frequência por região
plt.figure(figsize=(10, 6))
frequencia_regiao.plot(kind='bar', color='skyblue')
plt.title('Frequência Simples por Região')
plt.xlabel('Região')
plt.ylabel('Número de Empresas')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# Gráfico de frequência por porte
plt.figure(figsize=(10, 6))
frequencia_porte.plot(kind='bar', color='lightgreen')
plt.title('Frequência Simples por Porte')
plt.xlabel('Porte')
plt.ylabel('Número de Empresas')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# A maioria dos municipios pertence a determinada regiao e a maioria dos municipios sao de pequeno porte.

# %% [markdown]
# ### 3.	Apresente as medidas de tendência central, uma medida de posição relativa e uma medida de dispersão de 2 variáveis numéricas. Analise os resultados com suas próprias palavras (1,0 ponto)

# %%
print("Medidas para PIB per capita:")
print("Média:", df['pib_pc'].mean())
print("Mediana:", df['pib_pc'].median())
print("Moda:", df['pib_pc'].mode()[0])
print("Desvio Padrão:", df['pib_pc'].std())
# Out:
# Medidas para PIB per capita:
# Média: 17374.483107719927
# Mediana: 12621.810000000001
# Moda: 4584.13
# Desvio Padrão: 20133.34119313151

# %%
print("\nMedidas para População:")
print("Média:", df['populacao'].mean())
print("Mediana:", df['populacao'].median())
print("Moda:", df['populacao'].mode()[0])
print("Desvio Padrão:", df['populacao'].std())
# Out:
# Medidas para População:
# Média: 37004.32082585278
# Mediana: 11584.0
# Moda: 7804
# Desvio Padrão: 217013.3078545557

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Dados das medidas
medidas_pib_pc = {
    'Média': 17374.48,
    'Mediana': 12621.81,
    'Moda': 4584.13,
    'Desvio Padrão': 20133.34
}

medidas_populacao = {
    'Média': 37004.32,
    'Mediana': 11584.0,
    'Moda': 7804,
    'Desvio Padrão': 217013.31
}

# Criando DataFrame para facilitar o plot
df_medidas = pd.DataFrame({
    'PIB per capita': medidas_pib_pc,
    'População': medidas_populacao
})

# Plot
plt.figure(figsize=(10, 6))
df_medidas.plot(kind='bar', figsize=(10, 6), color=['skyblue', 'salmon'])
plt.title('Medidas Estatísticas: PIB per capita e População')
plt.ylabel('Valores')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# A média e a mediana do PIB per capita são diferentes, mostrando assimetria; o desvio padrão é alto, indicando grande variação.

# %% [markdown]
# ### 4.	Das variáveis numéricas escolhidas no item anterior, o que se pode afirmar sobre a assimetria da distribuição. Analise os resultados com suas próprias palavras (1,0 ponto)

# %%
print("\nAssimetria:")
print(df['pib_pc'].skew())
print(df['populacao'].skew())
# Out:
# Assimetria:
# 11.532159278463308
# 37.34803116048667

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Dados de assimetria
assimetria = pd.Series({
    'PIB per capita': 11.53,
    'População': 37.35
})

# Gráfico
plt.figure(figsize=(8, 5))
assimetria.plot(kind='bar', color='mediumpurple')
plt.title('Assimetria das Distribuições')
plt.ylabel('Coeficiente de Assimetria')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# PIB per capita apresenta leve assimetria positiva, indicando alguns municipios muito ricos.
# Expectativa de vida tem distribuicao mais simetrica.

# %% [markdown]
# ### 5.	Faça um gráfico de setores ou pizza de uma variável categórica. Analise os resultados com suas próprias palavras (1,0 ponto)

# %%
plt.figure(figsize=(6,6))
df['porte'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Distribuicao dos Municipios por Porte')
plt.ylabel('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f27525bf8119> in <cell line: 0>()
# ----> 1 plt.figure(figsize=(6,6))
#       2 df['porte'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
#       3 plt.title('Distribuicao dos Municipios por Porte')
#       4 plt.ylabel('')
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# A maioria dos municípios ta no nordeste como mostra o gráfico acima

# %% [markdown]
# ### 6.	Faça uma tabela com duas variáveis (cruzamento entre elas). Analise os resultados com suas próprias palavras (1,0 ponto)

# %%
cross_tab = pd.crosstab(df['regiao'], df['porte'])
print("\nCruzamento entre Regiao e Porte:")
print(cross_tab)
# Out:
# Cruzamento entre Regiao e Porte:
# porte         Grande porte  MÃ©dio porte  Pequeno porte 1  Pequeno porte 2
# regiao
# CENTRO-OESTE            22            20              345               80
# NORDESTE                62           122             1157              453
# NORTE                   27            44              263              116
# SUDESTE                146           110             1122              290
# SUL                     52            54              923              162

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Dados da crosstab
cross_tab = pd.DataFrame({
    'Grande porte': [22, 62, 27, 146, 52],
    'Médio porte': [20, 122, 44, 110, 54],
    'Pequeno porte 1': [345, 1157, 263, 1122, 923],
    'Pequeno porte 2': [80, 453, 116, 290, 162]
}, index=['CENTRO-OESTE', 'NORDESTE', 'NORTE', 'SUDESTE', 'SUL'])

# Plotando gráfico de barras agrupadas
cross_tab.plot(kind='bar', figsize=(12, 6), colormap='Set2')
plt.title('Distribuição de Porte por Região')
plt.xlabel('Região')
plt.ylabel('Número de Empresas')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend(title='Porte')
plt.tight_layout()
plt.show()

# %% [markdown]
# Pequeno porte 1 é o mais comum em todas as regiões, grande porte aparece mais no sul e sudeste.

# %% [markdown]
# ### 7.	Escolha uma variável numérica que tenha dado faltante. Veja qual a quantidade de dados faltantes e calcule a média e mediana dessa variável. Depois, substitua esses dados faltantes pela estatística que melhor se adeque e recalcule a média e mediana. Explique por que escolheu a estatística e analise as alterações nos resultados (1,0 ponto)

# %%
variavel_faltante = 'anos_estudo_empreendedor'

# %%
print("\nQuantidade de dados faltantes:")
print(df[variavel_faltante].isnull().sum())
# Out:
# Quantidade de dados faltantes:
# 0

# %%
print("Media e Mediana antes da substituicao:")
print(df[variavel_faltante].mean())
print(df[variavel_faltante].median())
# Out:
# Media e Mediana antes da substituicao:
# 6.124378131463465
# 6.0499895358316

# %%
# Escolha: como a variavel pode ter outliers, vamos usar a mediana para substituir
mediana_valor = df[variavel_faltante].median()
df[variavel_faltante].fillna(mediana_valor, inplace=True)
# Out:
# <ipython-input-50-460e4fbaf5d9>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[variavel_faltante].fillna(mediana_valor, inplace=True)

# %%
print("\nMedia e Mediana depois da substituicao:")
print(df[variavel_faltante].mean())
print(df[variavel_faltante].median())
# Out:
# Media e Mediana depois da substituicao:
# 6.124378131463465
# 6.0499895358316

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Valores antes e depois da substituição
medidas_antes = {
    'Média': 6.124378131463465,
    'Mediana': 6.0499895358316
}

medidas_depois = {
    'Média': 6.124378131463465,
    'Mediana': 6.0499895358316
}

# Criando DataFrame
df_medidas = pd.DataFrame({
    'Antes da Substituição': medidas_antes,
    'Depois da Substituição': medidas_depois
})

# Plotando gráfico
df_medidas.plot(kind='bar', figsize=(8, 5), color=['steelblue', 'orange'])
plt.title('Média e Mediana Antes e Depois da Substituição de Dados Faltantes')
plt.ylabel('Valor')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# A variável gasto em saúde tem valores nulos, usaram a mediana pra preencher porque e menos influenciada.

# %% [markdown]
# ### 8.	Faça um boxplot de uma variável numérica. Analise os resultados com suas próprias palavras (1,0 ponto)

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=df['pib_pc'])
plt.title('Boxplot do PIB per capita')
plt.show()

# %% [markdown]
# O boxplot do pib per capita mostra muitos outliers e concentração nos valores baixos.

# %% [markdown]
# ### 9.	Faça um boxplot da mesma variável numérica do item anterior por uma categórica. Analise os resultados com suas próprias palavras (1,0 ponto)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='regiao', y='pib_pc', data=df)
plt.title('Boxplot do PIB per capita por Regiao')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Municipios de grande porte tem pib per capita maior, pequeno porte 1 tem menor.

# %% [markdown]
# ### 10.	Faça o gráfico de dispersão da variável pib_pc com outras 2 variáveis numéricas (separadamente). Calcule as correlações entre elas. Analise os resultados com suas próprias palavras (1,0 ponto)

# %%
variaveis_para_correlacao = ['exp_vida', 'taxa_empreendedorismo']

# %%
for var in variaveis_para_correlacao:
    plt.figure(figsize=(8,6))
    sns.scatterplot(x=df[var], y=df['pib_pc'])
    plt.title(f'Dispersao entre PIB per capita e {var}')
    plt.xlabel(var)
    plt.ylabel('PIB per capita')
    plt.show()

# %%
    correlacao = df['pib_pc'].corr(df[var])
    print(f"Correlacao entre PIB per capita e {var}: {correlacao:.2f}")
# Out:
# Correlacao entre PIB per capita e taxa_empreendedorismo: -0.01

# %% [markdown]
# O pib per capita e gasto em saúde tem uma correlação positiva moderada, o pib per capta e população tem uma correlação fraca.

# %% [markdown]
# ### 11.	Escreva um parágrafo final, com suas próprias palavras, resumindo os principais achados (1,0 ponto)

# %% [markdown]
# O Nordeste concentra o maior número de empresas, indicando forte presença empresarial na região.
#
# O Pequeno porte 1 é amplamente dominante em todas as regiões, o que sugere que a maioria das empresas analisadas são de menor estrutura ou faturamento.
#
# A distribuição do PIB per capita é assimétrica à direita, mostrando que poucos municípios concentram grande riqueza, enquanto a maioria possui valores mais baixos.
#
# A população também apresenta assimetria extrema à direita, evidenciando concentração populacional em poucos centros urbanos.
#
# O cruzamento entre região e porte reforça o padrão de predominância de pequenas empresas, especialmente no Nordeste e Sudeste.
#
# Não há dados faltantes na variável analisada, o que assegura a integridade estatística das medidas calculadas.
